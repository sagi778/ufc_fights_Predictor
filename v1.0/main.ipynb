# %%
from func_def import *

# %%
events = get_links(url='http://www.ufcstats.com/statistics/events/completed?page=all')
events.date = pd.to_datetime(events.date)
events = events[events.date < get_current_date()].reset_index(drop=True)
events.tail()
# Out:
#           date                                          event_url
# 656 1995-09-08  http://www.ufcstats.com/event-details/1c3f5e85...
# 657 1995-07-14  http://www.ufcstats.com/event-details/dedc3bb4...
# 658 1995-04-07  http://www.ufcstats.com/event-details/b60391da...
# 659 1994-12-16  http://www.ufcstats.com/event-details/1a49e067...
# 660 1994-09-09  http://www.ufcstats.com/event-details/a6a9ab5a...

# %%
#get existing data
try:
    exist_data = pd.read_csv('data_pre_processed.csv',index_col=0)
    exist_events_url = list(np.unique(exist_data.event_url))
except:
    print('Cant find data_pre_processed.csv')
    exist_data = []
    exist_events_url = []

print(f'Current Existing events: {len(exist_events_url)}')
# Out:
# Current Existing events: 648

# %%
#get new data
new_events = list(set(events.event_url) - set(exist_events_url))
#new_events = events
print(f'New events: {len(new_events)}')
# Out:
# New events: 661

# %%
new_data = []
for url,time in tqdm(zip(new_events['event_url'],new_events['date'])):
    try:
        #print(f'{url} {time}')
        new_data.extend(get_event_data(EVENT_URL=url,EVENT_TIME=time))
    except:
        continue   

data = pd.concat([exist_data,pd.DataFrame(new_data)])
data.tail(3)
# Out:
# 0it [00:00, ?it/s]
# 661it [3:17:26, 17.92s/it]
#                                                     url  \
# 7204  http://www.ufcstats.com/fight-details/ccee020b...
# 7205  http://www.ufcstats.com/fight-details/4b9ae533...
# 7206  http://www.ufcstats.com/fight-details/4acab678...
#
#                                               event_url result       fighter  \
# 7204  http://www.ufcstats.com/event-details/a6a9ab5a...      W  Johnny Rhode
# 7205  http://www.ufcstats.com/event-details/a6a9ab5a...      W  Patrick Smit
# 7206  http://www.ufcstats.com/event-details/a6a9ab5a...      W   Scott Morri
#
#            opponent             title      method round   time         format  \
# 7204   David Levick  Open Weight Bout      KO/TKO     1  12:13  No Time Limit
# 7205      Ray Wizar  Open Weight Bout  Submission     1   0:58  No Time Limit
# 7206  Sean Daughert  Open Weight Bout  Submission     1   0:20  No Time Limit
#
#      f_head_sig_str f_body_sig_str f_leg_sig_str f_distance_sig_str  \
# 7204          9of15           1of1          1of1               1of1
# 7205           0of0           1of1          0of0               0of0
# 7206           1of1           0of0          0of0               0of0
#
#      f_clinch_sig_str f_ground_sig_str o_head_sig_str o_body_sig_str  \
# 7204             1of1            9of15           4of5           0of0
# 7205             1of1             0of0           0of0           0of0
# 7206             1of1             0of0           0of2           0of0
#
#      o_leg_sig_str o_distance_sig_str o_clinch_sig_str o_ground_sig_str  \
# 7204          0of0               1of2             2of2             1of1
# 7205          1of1               1of1             0of0             0of0
# 7206          0of2               0of3             0of1             0of0
#
#      f_sig_str_head f_sig_str_body f_sig_str_leg f_sig_str_dist  \
# 7204            81%             9%            9%             9%
# 7205             0%           100%            0%             0%
# 7206           100%             0%            0%             0%
#
#      f_sig_str_clinch f_sig_str_ground o_sig_str_head o_sig_str_body  \
# 7204               9%              81%           100%             0%
# 7205             100%               0%             0%             0%
# 7206             100%               0%             0%             0%
#
#      o_sig_str_leg o_sig_str_dist o_sig_str_clinch o_sig_str_ground       date
# 7204            0%            25%              50%              25% 1994-09-09
# 7205          100%           100%               0%               0% 1994-09-09
# 7206            0%             0%               0%               0% 1994-09-09

# %%
pd.DataFrame(data).to_csv('data_pre_processed.csv',index=[0])

# %%
pd.DataFrame(data).tail(3)
# Out:
#                                                     url  \
# 7204  http://www.ufcstats.com/fight-details/ccee020b...
# 7205  http://www.ufcstats.com/fight-details/4b9ae533...
# 7206  http://www.ufcstats.com/fight-details/4acab678...
#
#                                               event_url result       fighter  \
# 7204  http://www.ufcstats.com/event-details/a6a9ab5a...      W  Johnny Rhode
# 7205  http://www.ufcstats.com/event-details/a6a9ab5a...      W  Patrick Smit
# 7206  http://www.ufcstats.com/event-details/a6a9ab5a...      W   Scott Morri
#
#            opponent             title      method round   time         format  \
# 7204   David Levick  Open Weight Bout      KO/TKO     1  12:13  No Time Limit
# 7205      Ray Wizar  Open Weight Bout  Submission     1   0:58  No Time Limit
# 7206  Sean Daughert  Open Weight Bout  Submission     1   0:20  No Time Limit
#
#      f_head_sig_str f_body_sig_str f_leg_sig_str f_distance_sig_str  \
# 7204          9of15           1of1          1of1               1of1
# 7205           0of0           1of1          0of0               0of0
# 7206           1of1           0of0          0of0               0of0
#
#      f_clinch_sig_str f_ground_sig_str o_head_sig_str o_body_sig_str  \
# 7204             1of1            9of15           4of5           0of0
# 7205             1of1             0of0           0of0           0of0
# 7206             1of1             0of0           0of2           0of0
#
#      o_leg_sig_str o_distance_sig_str o_clinch_sig_str o_ground_sig_str  \
# 7204          0of0               1of2             2of2             1of1
# 7205          1of1               1of1             0of0             0of0
# 7206          0of2               0of3             0of1             0of0
#
#      f_sig_str_head f_sig_str_body f_sig_str_leg f_sig_str_dist  \
# 7204            81%             9%            9%             9%
# 7205             0%           100%            0%             0%
# 7206           100%             0%            0%             0%
#
#      f_sig_str_clinch f_sig_str_ground o_sig_str_head o_sig_str_body  \
# 7204               9%              81%           100%             0%
# 7205             100%               0%             0%             0%
# 7206             100%               0%             0%             0%
#
#      o_sig_str_leg o_sig_str_dist o_sig_str_clinch o_sig_str_ground       date
# 7204            0%            25%              50%              25% 1994-09-09
# 7205          100%           100%               0%               0% 1994-09-09
# 7206            0%             0%               0%               0% 1994-09-09
