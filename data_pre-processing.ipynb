# %%
# %run func_def.ipynb
# Out:
# imports loaded.
#
# > Pre-Processing func:
#     get_height(item)
#     get_weight(item)
#     get_reach(item)
#     get_std_reach(item, height, reach_list, height_list)
#     get_age(item)
#     get_std_age(item, age_list)
#     get_win_prob(name, date, df)
#     get_lose_streak_data_frame(name, date, df)
#     get_win_streak_data_frame(name, date, df)
#     get_streak_data_frame(name, date, df)
#     get_win_streak(name, date, df)
#     get_lose_streak(name, date, df)
#     get_fighter_stats(name, data )
#     add_columns(data, column_list)
#
# > outlier_cleaning func:
#     set_outlier_detection_model(X_columns, data)
#
# > Feature Engineering func:
#     get_stat(index, data, stat='height', fo='')
#     get_swaped_row(index, data)
#     get_wins(combo, data)
#     get_wins_ratio(combo, data)
#
# > stats_model_training func:
#     set_lower_cases(string)
#     set_train_test(X_columns, y_columns, data, test_size=0.3, valid_size=0.3)
#     set_xgboost_reg(X_columns, y_columns, data, n=200, learning_rate=0.2, subsample=0.4, max_depth=5)
#     get_sig_features(data, sig_r)
#     get_r_score(X, y)
#     load_trained_model(filename_path)
#     set_random_forest_reg(X_columns, y_columns, data)
#     set_predictions(model, data, X_columns, y_columns)
#     get_mean_percentage_error(act, pred)
#     get_rmse(act, pred)
#     save_trained_model(model, path)
#
# > result_model_training func:
#     set_xgboost_clf(X_columns, y_columns, data, n=200, learning_rate=0.2, subsample=0.4, max_depth=5)
#     set_random_forest_clf(X_columns, y_columns, data)
#     get_clf_grad_desc_step( X_columns, y_columns, data, neighbors)
#     get_model_evaluation(data)
#     get_accuracy(act, pred)
#
# > method_model_training func:
#     set_method_predictions(model, data, X_columns, y_columns)
#     get_method_grad_desc_step(X_columns, y_columns, data, n_estimators)
#
# > Predictor func:
#     get_current_date()
#     get_win_perc(fighter, data)
#     get_lose_streak(fighter, data)
#     get_win_streak(fighter, data)
#     get_td_avg(fighter, data)
#     get_td_acc(fighter, data)
#     get_td_def(fighter, data)
#     get_str_acc(fighter, data)
#     get_str_def(fighter, data)
#     get_sub_avg(fighter, data)
#     get_sapm(fighter, data)
#     get_slpm(fighter, data)
#     get_stance(fighter, data)
#     get_stance_wins_ratio(fighter, data)
#     set_new_fight(fighter, opponent, data)
#     set_knn_predictor(X_columns, y_columns, data, n=5)
#     set_knn_predictions(model, data, X_columns, y_columns)
#     set_knn_clf_predictor(X_columns, y_columns, data, neighbors)
#     set_pred_results(model, data, X_columns, y_columns)
#     get_fighters_stats(fighter, opponent, data)
#     get_winner(match)
#
# > micro_model_training func:
#     set_result_column(fighter,data)
#     get_my_losses(fighter, data)
#     get_my_wins(fighter, data)
#     get_synt_loss(fighter)
#     get_loss_value(values)

# %% [markdown]
# # <span style='color:green'> **[done]** </span> Exploratory Data Analysis

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> ufc_fighters_stats.csv exploration

# %%
loc = '../../web_scrapers/data/'
file1 = 'ufc_fighters_stats.csv'
df = pd.read_csv(loc+file1)
df.tail(3)
# Out:
#                 name  wins  losses draws height   weight reach    stance  \
# 2370  Sijara Eubanks     8       7     0   5'4"  125lbs.   67"  Orthodox
# 2371     Andre Ewell    17       9     0   5'8"  145lbs.   75"  Southpaw
# 2372     Matt Sayles     8       4     0   5'7"  155lbs.   68"  Orthodox
#
#              dob  slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg  \
# 2370  Apr27,1985  4.30     43%  3.43     57%    1.90    44%    66%      0.3
# 2371  Jan21,1988  4.28     40%  4.87     51%    0.36    75%    72%      0.1
# 2372  Feb21,1994  4.83     41%  2.81     61%    0.36    16%    81%      0.7
#
#      last_update  last_match  \
# 2370  04-18-2023  12-18-2021
# 2371  04-18-2023  12-18-2021
# 2372  04-18-2023  12-18-2021
#
#                                                     url
# 2370  http://ufcstats.com/fighter-details/4234f0097c...
# 2371  http://ufcstats.com/fighter-details/5f6f049d54...
# 2372  http://ufcstats.com/fighter-details/5b8ba8f551...

# %% [markdown]
# ## Column's Legend:
# ****
# * <span style='color:blue'> **SLpM** </span> - Significant Strikes Landed per Minute
# * <span style='color:blue'> **Str. Acc.** </span> - Significant Striking Accuracy
# * <span style='color:blue'> **SApM** </span> - Significant Strikes Absorbed per Minute
# * <span style='color:blue'> **Str. Def.** </span> - Significant Strike Defence (the % of opponents strikes that did not land)
# * <span style='color:blue'> **TD Avg.** </span> - Average Takedowns Landed per 15 minutes
# * <span style='color:blue'> **TD Acc.** </span> - Takedown Accuracy
# * <span style='color:blue'> **TD Def.** </span> - Takedown Defense (the % of opponents TD attempts that did not land)
# * <span style='color:blue'> **Sub. Avg.** </span> - Average Submissions Attempted per 15 minutes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2373 entries, 0 to 2372
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2373 non-null   object
#  1   wins         2373 non-null   int64
#  2   losses       2373 non-null   int64
#  3   draws        2373 non-null   object
#  4   height       2373 non-null   object
#  5   weight       2373 non-null   object
#  6   reach        2373 non-null   object
#  7   stance       2285 non-null   object
#  8   dob          2373 non-null   object
#  9   slpm         2373 non-null   float64
#  10  str_acc      2373 non-null   object
#  11  sapm         2373 non-null   float64
#  12  str_def      2373 non-null   object
#  13  td_avg       2373 non-null   float64
#  14  td_acc       2373 non-null   object
#  15  td_def       2373 non-null   object
#  16  sub_avg      2373 non-null   float64
#  17  last_update  2373 non-null   object
#  18  last_match   2283 non-null   object
#  19  url          2373 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 370.9+ KB

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> height

# %%
for i in range(0,len(df['height'])):
    df.loc[i,'height'] = get_height(df.loc[i,'height']) 
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2373 entries, 0 to 2372
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2373 non-null   object
#  1   wins         2373 non-null   int64
#  2   losses       2373 non-null   int64
#  3   draws        2373 non-null   object
#  4   height       2352 non-null   object
#  5   weight       2373 non-null   object
#  6   reach        2373 non-null   object
#  7   stance       2285 non-null   object
#  8   dob          2373 non-null   object
#  9   slpm         2373 non-null   float64
#  10  str_acc      2373 non-null   object
#  11  sapm         2373 non-null   float64
#  12  str_def      2373 non-null   object
#  13  td_avg       2373 non-null   float64
#  14  td_acc       2373 non-null   object
#  15  td_def       2373 non-null   object
#  16  sub_avg      2373 non-null   float64
#  17  last_update  2373 non-null   object
#  18  last_match   2283 non-null   object
#  19  url          2373 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 370.9+ KB

# %% [markdown]
# #### replacing null values with mean >

# %%
height_list = df['height'][df['height']!=None]
df.height = df.height.fillna(np.round(np.mean(height_list),2))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2373 entries, 0 to 2372
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2373 non-null   object
#  1   wins         2373 non-null   int64
#  2   losses       2373 non-null   int64
#  3   draws        2373 non-null   object
#  4   height       2373 non-null   float64
#  5   weight       2373 non-null   object
#  6   reach        2373 non-null   object
#  7   stance       2285 non-null   object
#  8   dob          2373 non-null   object
#  9   slpm         2373 non-null   float64
#  10  str_acc      2373 non-null   object
#  11  sapm         2373 non-null   float64
#  12  str_def      2373 non-null   object
#  13  td_avg       2373 non-null   float64
#  14  td_acc       2373 non-null   object
#  15  td_def       2373 non-null   object
#  16  sub_avg      2373 non-null   float64
#  17  last_update  2373 non-null   object
#  18  last_match   2283 non-null   object
#  19  url          2373 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 370.9+ KB

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> weight

# %%
for i in range(0,len(df['weight'])):
    df.loc[i,'weight'] = get_weight(df.loc[i,'weight']) 
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2373 entries, 0 to 2372
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2373 non-null   object
#  1   wins         2373 non-null   int64
#  2   losses       2373 non-null   int64
#  3   draws        2373 non-null   object
#  4   height       2373 non-null   float64
#  5   weight       2355 non-null   object
#  6   reach        2373 non-null   object
#  7   stance       2285 non-null   object
#  8   dob          2373 non-null   object
#  9   slpm         2373 non-null   float64
#  10  str_acc      2373 non-null   object
#  11  sapm         2373 non-null   float64
#  12  str_def      2373 non-null   object
#  13  td_avg       2373 non-null   float64
#  14  td_acc       2373 non-null   object
#  15  td_def       2373 non-null   object
#  16  sub_avg      2373 non-null   float64
#  17  last_update  2373 non-null   object
#  18  last_match   2283 non-null   object
#  19  url          2373 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 370.9+ KB

# %% [markdown]
# #### drop fighters which weight is unknown>

# %%
df = df[~df.weight.isna()].reset_index(drop=True)
df.tail(3)
# Out:
#                 name  wins  losses draws  height weight reach    stance  \
# 2352  Sijara Eubanks     8       7     0  162.56  56.25   67"  Orthodox
# 2353     Andre Ewell    17       9     0  172.72  65.25   75"  Southpaw
# 2354     Matt Sayles     8       4     0  170.18  69.75   68"  Orthodox
#
#              dob  slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg  \
# 2352  Apr27,1985  4.30     43%  3.43     57%    1.90    44%    66%      0.3
# 2353  Jan21,1988  4.28     40%  4.87     51%    0.36    75%    72%      0.1
# 2354  Feb21,1994  4.83     41%  2.81     61%    0.36    16%    81%      0.7
#
#      last_update  last_match  \
# 2352  04-18-2023  12-18-2021
# 2353  04-18-2023  12-18-2021
# 2354  04-18-2023  12-18-2021
#
#                                                     url
# 2352  http://ufcstats.com/fighter-details/4234f0097c...
# 2353  http://ufcstats.com/fighter-details/5f6f049d54...
# 2354  http://ufcstats.com/fighter-details/5b8ba8f551...

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> Reach

# %%
df.reach.unique()
# Out:
# array(['70"', '75"', '63"', '68"', '67"', '78"', '71"', '62"', '76"',
#        '73"', '72"', '74"', '69"', '64"', '65"', '82"', '77"', '61"',
#        '80"', '66"', '79"', '84"', '--', '81"', '60"', '58"', '83"',
#        '59"'], dtype=object)

# %%
for i in range(0,len(df['reach'])):
    df.loc[i,'reach'] = get_reach(df.loc[i,'reach']) 
    
df.head(3)
# Out:
#              name  wins  losses draws  height weight   reach    stance  \
# 0       Ryan Hall     9       2     0  177.80  65.25   177.8  Southpaw
# 1     Maki Pitolo    13       9     0  177.80  83.25   190.5  Orthodox
# 2  Mallory Martin     7       5     0  162.56  51.75  160.02  Orthodox
#
#           dob  slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg  \
# 0  Feb22,1985  2.38     50%  1.33     65%    0.22     9%     0%      2.2
# 1  Nov24,1990  4.10     44%  3.93     55%    2.24    52%    50%      0.8
# 2  Jan29,1994  4.42     48%  6.64     55%    2.28    43%    25%      0.3
#
#   last_update  last_match                                                url
# 0  04-18-2023  12-11-2021  http://ufcstats.com/fighter-details/8866c6f509...
# 1  04-18-2023  12-04-2021  http://ufcstats.com/fighter-details/c549573c0d...
# 2  04-18-2023  12-04-2021  http://ufcstats.com/fighter-details/19b7738321...

# %% [markdown]
# #### replacing null values with "standard reach" ( =mean(reach/height)*height ) >

# %%
y = pd.to_numeric(df.reach[~df.reach.isna()])
x = pd.to_numeric(df.height[~df.reach.isna()])
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='height', ylabel='reach'>

# %%
null_indexs = df[df.reach.isna()].index

for i in null_indexs:
    df.loc[i, 'reach'] = get_std_reach(df.loc[i, 'reach'],df.loc[i,'height'], df['reach'], df['height']) 
    
print('Null changed: ' + str(len(null_indexs)))
df.info()
# Out:
# Null changed: 639
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2355 entries, 0 to 2354
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2355 non-null   object
#  1   wins         2355 non-null   int64
#  2   losses       2355 non-null   int64
#  3   draws        2355 non-null   object
#  4   height       2355 non-null   float64
#  5   weight       2355 non-null   object
#  6   reach        2355 non-null   object
#  7   stance       2282 non-null   object
#  8   dob          2355 non-null   object
#  9   slpm         2355 non-null   float64
#  10  str_acc      2355 non-null   object
#  11  sapm         2355 non-null   float64
#  12  str_def      2355 non-null   object
#  13  td_avg       2355 non-null   float64
#  14  td_acc       2355 non-null   object
#  15  td_def       2355 non-null   object
#  16  sub_avg      2355 non-null   float64
#  17  last_update  2355 non-null   object
#  18  last_match   2265 non-null   object
#  19  url          2355 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 368.1+ KB

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> stance

# %%
df.stance.unique()
# Out:
# array(['Southpaw', 'Orthodox', nan, 'Switch', 'OpenStance', 'Sideways'],
#       dtype=object)

# %%
null_indexs = df[df.stance.isna()].index

for i in null_indexs:
    df.loc[i, 'stance'] = 'Orthodox' 
    
print('Null changed: ' + str(len(null_indexs)))
print(df.stance.unique())
df.info()
# Out:
# Null changed: 73
# ['Southpaw' 'Orthodox' 'Switch' 'OpenStance' 'Sideways']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2355 entries, 0 to 2354
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2355 non-null   object
#  1   wins         2355 non-null   int64
#  2   losses       2355 non-null   int64
#  3   draws        2355 non-null   object
#  4   height       2355 non-null   float64
#  5   weight       2355 non-null   object
#  6   reach        2355 non-null   object
#  7   stance       2355 non-null   object
#  8   dob          2355 non-null   object
#  9   slpm         2355 non-null   float64
#  10  str_acc      2355 non-null   object
#  11  sapm         2355 non-null   float64
#  12  str_def      2355 non-null   object
#  13  td_avg       2355 non-null   float64
#  14  td_acc       2355 non-null   object
#  15  td_def       2355 non-null   object
#  16  sub_avg      2355 non-null   float64
#  17  last_update  2355 non-null   object
#  18  last_match   2265 non-null   object
#  19  url          2355 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 368.1+ KB

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> Age

# %%
df = df.rename(columns = {'dob':'age'})
print(df.age.unique())
df.head(0)
# Out:
# ['Feb22,1985' 'Nov24,1990' 'Jan29,1994' ... 'Apr27,1985' 'Jan21,1988'
#  'Feb21,1994']
# Empty DataFrame
# Columns: [name, wins, losses, draws, height, weight, reach, stance, age, slpm, str_acc, sapm, str_def, td_avg, td_acc, td_def, sub_avg, last_update, last_match, url]
# Index: []

# %%
for i in range(0,len(df['age'])):
    
    if df.loc[i, 'age'] != None:
        df.loc[i, 'age'] = get_age(df.loc[i, 'age']) 
    
df.age.unique()
# Out:
# array([38, 33, 29, 37, 36, 39, 34, 42, 31, 30, 28, 32, 35, 40, 45, 27, 46,
#        44, 43, 41, 48, 47, 49, 26, 53, 51, 50, 52, None, 54, 60, 55, 56,
#        59, 57, 58, 62, 65, 80, 63, 24, 19, 25, 23, 21, 22], dtype=object)

# %% [markdown]
# #### replacing null with standard age >

# %%
ax = sns.histplot(x=df["age"])

# %%
null_indexs = df[df.age.isna()].index
for i in null_indexs:
    df.loc[i, 'age'] = get_std_age(item=df.loc[i,'age'], age_list=df.age)

df.age.unique()
# Out:
# array([38, 33, 29, 37, 36, 39, 34, 42, 31, 30, 28, 32, 35, 40, 45, 27, 46,
#        44, 43, 41, 48, 47, 49, 26, 53, 51, 50, 52, 37.93, 54, 60, 55, 56,
#        59, 57, 58, 62, 65, 80, 63, 24, 19, 25, 23, 21, 22], dtype=object)

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> statistics % pre-processing

# %%
df.head(3)
# Out:
#              name  wins  losses draws  height weight   reach    stance age  \
# 0       Ryan Hall     9       2     0  177.80  65.25   177.8  Southpaw  38
# 1     Maki Pitolo    13       9     0  177.80  83.25   190.5  Orthodox  33
# 2  Mallory Martin     7       5     0  162.56  51.75  160.02  Orthodox  29
#
#    slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg last_update  \
# 0  2.38     50%  1.33     65%    0.22     9%     0%      2.2  04-18-2023
# 1  4.10     44%  3.93     55%    2.24    52%    50%      0.8  04-18-2023
# 2  4.42     48%  6.64     55%    2.28    43%    25%      0.3  04-18-2023
#
#    last_match                                                url
# 0  12-11-2021  http://ufcstats.com/fighter-details/8866c6f509...
# 1  12-04-2021  http://ufcstats.com/fighter-details/c549573c0d...
# 2  12-04-2021  http://ufcstats.com/fighter-details/19b7738321...

# %%
for column in ['str_acc','str_def','td_acc','td_def']:
    
    for i in range(0,len(df)):

        item = str(df.loc[i,column])
        df.loc[i,column] = float(item[0:item.find('%')])/100

df.head(3)
# Out:
#              name  wins  losses draws  height weight   reach    stance age  \
# 0       Ryan Hall     9       2     0  177.80  65.25   177.8  Southpaw  38
# 1     Maki Pitolo    13       9     0  177.80  83.25   190.5  Orthodox  33
# 2  Mallory Martin     7       5     0  162.56  51.75  160.02  Orthodox  29
#
#    slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg last_update  \
# 0  2.38     0.5  1.33    0.65    0.22   0.09    0.0      2.2  04-18-2023
# 1  4.10    0.44  3.93    0.55    2.24   0.52    0.5      0.8  04-18-2023
# 2  4.42    0.48  6.64    0.55    2.28   0.43   0.25      0.3  04-18-2023
#
#    last_match                                                url
# 0  12-11-2021  http://ufcstats.com/fighter-details/8866c6f509...
# 1  12-04-2021  http://ufcstats.com/fighter-details/c549573c0d...
# 2  12-04-2021  http://ufcstats.com/fighter-details/19b7738321...

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> losses

# %%
null_indexs = df[df.losses.isna()].index
for i in null_indexs:
    df.loc[i,'losses'] = int(0)
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2355 entries, 0 to 2354
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2355 non-null   object
#  1   wins         2355 non-null   int64
#  2   losses       2355 non-null   int64
#  3   draws        2355 non-null   object
#  4   height       2355 non-null   float64
#  5   weight       2355 non-null   object
#  6   reach        2355 non-null   object
#  7   stance       2355 non-null   object
#  8   age          2355 non-null   object
#  9   slpm         2355 non-null   float64
#  10  str_acc      2355 non-null   object
#  11  sapm         2355 non-null   float64
#  12  str_def      2355 non-null   object
#  13  td_avg       2355 non-null   float64
#  14  td_acc       2355 non-null   object
#  15  td_def       2355 non-null   object
#  16  sub_avg      2355 non-null   float64
#  17  last_update  2355 non-null   object
#  18  last_match   2265 non-null   object
#  19  url          2355 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 368.1+ KB

# %%
stat_df = df
stat_df.head(3)
# Out:
#              name  wins  losses draws  height weight   reach    stance age  \
# 0       Ryan Hall     9       2     0  177.80  65.25   177.8  Southpaw  38
# 1     Maki Pitolo    13       9     0  177.80  83.25   190.5  Orthodox  33
# 2  Mallory Martin     7       5     0  162.56  51.75  160.02  Orthodox  29
#
#    slpm str_acc  sapm str_def  td_avg td_acc td_def  sub_avg last_update  \
# 0  2.38     0.5  1.33    0.65    0.22   0.09    0.0      2.2  04-18-2023
# 1  4.10    0.44  3.93    0.55    2.24   0.52    0.5      0.8  04-18-2023
# 2  4.42    0.48  6.64    0.55    2.28   0.43   0.25      0.3  04-18-2023
#
#    last_match                                                url
# 0  12-11-2021  http://ufcstats.com/fighter-details/8866c6f509...
# 1  12-04-2021  http://ufcstats.com/fighter-details/c549573c0d...
# 2  12-04-2021  http://ufcstats.com/fighter-details/19b7738321...

# %% [markdown]
# ## <span style='color:green'> **[done]** </span> ufc_fights_stats.csv exploration

# %%
file = 'ufc_matches_stats.csv'
df = pd.read_csv(loc+file)
df.tail(3)
# Out:
#      result        fighter         opponent f_kd o_kd f_str o_str f_td o_td  \
# 6440    win  Frank Hamaker  Thaddeus Luster    0    0     2     0    1    0
# 6441    win  Johnny Rhodes    David Levicki    0    0    11     4    1    0
# 6442    win  Patrick Smith       Ray Wizard    0    0     1     1    0    0
#
#      f_sub o_sub weight_class  method              type  round   time  \
# 6440     3     0  Open Weight     SUB           Keylock      1   4:52
# 6441     0     0  Open Weight  KO/TKO           Punches      1  12:13
# 6442     1     0  Open Weight     SUB  Guillotine Choke      1   0:58
#
#             date                                          event_url
# 6440  03-11-1994  http://ufcstats.com/event-details/a6a9ab5a824e...
# 6441  03-11-1994  http://ufcstats.com/event-details/a6a9ab5a824e...
# 6442  03-11-1994  http://ufcstats.com/event-details/a6a9ab5a824e...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6443 entries, 0 to 6442
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   result        6443 non-null   object
#  1   fighter       6443 non-null   object
#  2   opponent      6443 non-null   object
#  3   f_kd          6443 non-null   object
#  4   o_kd          6443 non-null   object
#  5   f_str         6443 non-null   object
#  6   o_str         6443 non-null   object
#  7   f_td          6443 non-null   object
#  8   o_td          6443 non-null   object
#  9   f_sub         6443 non-null   object
#  10  o_sub         6443 non-null   object
#  11  weight_class  6443 non-null   object
#  12  method        6443 non-null   object
#  13  type          3277 non-null   object
#  14  round         6443 non-null   int64
#  15  time          6443 non-null   object
#  16  date          6443 non-null   object
#  17  event_url     6443 non-null   object
# dtypes: int64(1), object(17)
# memory usage: 906.2+ KB

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> date

# %%
df.date = pd.to_datetime(df.date, format='%m-%d-%Y')
df.head(3)
# Out:
#   result            fighter           opponent f_kd o_kd f_str o_str f_td  \
# 0    win       Max Holloway       Arnold Allen    0    0   147    76    0
# 1    win      Edson Barboza  Billy Quarantillo    1    0    21    19    0
# 2    win  Azamat Murzakanov      Dustin Jacoby    1    0    67    64    1
#
#   o_td f_sub o_sub       weight_class  method  type  round  time       date  \
# 0    0     0     0      Featherweight   U-DEC   NaN      5  5:00 2023-04-15
# 1    0     0     0      Featherweight  KO/TKO  Knee      1  2:37 2023-04-15
# 2    1     0     0  Light Heavyweight   U-DEC   NaN      3  5:00 2023-04-15
#
#                                            event_url
# 0  http://ufcstats.com/event-details/15b1b21cd743...
# 1  http://ufcstats.com/event-details/15b1b21cd743...
# 2  http://ufcstats.com/event-details/15b1b21cd743...

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> drop 'draw' & 'nc' rows

# %%
df.result.unique()
# Out:
# array(['win', 'draw', 'nc'], dtype=object)

# %%
df = df[df.result == 'win'].reset_index(drop=True)
df.tail(3)
# Out:
#      result        fighter         opponent f_kd o_kd f_str o_str f_td o_td  \
# 6332    win  Frank Hamaker  Thaddeus Luster    0    0     2     0    1    0
# 6333    win  Johnny Rhodes    David Levicki    0    0    11     4    1    0
# 6334    win  Patrick Smith       Ray Wizard    0    0     1     1    0    0
#
#      f_sub o_sub weight_class  method              type  round   time  \
# 6332     3     0  Open Weight     SUB           Keylock      1   4:52
# 6333     0     0  Open Weight  KO/TKO           Punches      1  12:13
# 6334     1     0  Open Weight     SUB  Guillotine Choke      1   0:58
#
#            date                                          event_url
# 6332 1994-03-11  http://ufcstats.com/event-details/a6a9ab5a824e...
# 6333 1994-03-11  http://ufcstats.com/event-details/a6a9ab5a824e...
# 6334 1994-03-11  http://ufcstats.com/event-details/a6a9ab5a824e...

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> feature Win % column

# %%
df['f_win_perc'] = None
df['o_win_perc'] = None

i = 0
for fighter, opponent, date in tqdm(zip(df['fighter'], df['opponent'], df['date'])):
    #print('%d%% Completed' %(round((i/len(df))*100,2)), end ='\r')
    df.loc[i, 'f_win_perc'] = round(get_win_prob(name=fighter, date=date, df=df),2)
    df.loc[i, 'o_win_perc'] = round(get_win_prob(name=opponent, date=date, df=df),2)    
    i += 1

#print('100% Completed', end ='\r')    
df.head(3)
# Out:
# 6335it [00:20, 303.31it/s]
#   result            fighter           opponent f_kd o_kd f_str o_str f_td  \
# 0    win       Max Holloway       Arnold Allen    0    0   147    76    0
# 1    win      Edson Barboza  Billy Quarantillo    1    0    21    19    0
# 2    win  Azamat Murzakanov      Dustin Jacoby    1    0    67    64    1
#
#   o_td f_sub o_sub       weight_class  method  type  round  time       date  \
# 0    0     0     0      Featherweight   U-DEC   NaN      5  5:00 2023-04-15
# 1    0     0     0      Featherweight  KO/TKO  Knee      1  2:37 2023-04-15
# 2    1     0     0  Light Heavyweight   U-DEC   NaN      3  5:00 2023-04-15
#
#                                            event_url f_win_perc o_win_perc
# 0  http://ufcstats.com/event-details/15b1b21cd743...       0.73        1.0
# 1  http://ufcstats.com/event-details/15b1b21cd743...       0.59       0.71
# 2  http://ufcstats.com/event-details/15b1b21cd743...        1.0        0.8

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> feature Win/Lose streak column

# %%
df['f_win_strk'] = None
df['o_win_strk'] = None
df['f_lose_strk'] = None
df['o_lose_strk'] = None

for i in tqdm(range(len(df))):
    df.loc[i, 'f_win_strk'] = get_win_streak(name=df.loc[i,'fighter'],date=df.loc[i,'date'],df=df)
    df.loc[i, 'o_win_strk'] = get_win_streak(name=df.loc[i,'opponent'],date=df.loc[i,'date'],df=df)
    df.loc[i, 'f_lose_strk'] = get_lose_streak(name=df.loc[i,'fighter'],date=df.loc[i,'date'],df=df)
    df.loc[i, 'o_lose_strk'] = get_lose_streak(name=df.loc[i,'opponent'],date=df.loc[i,'date'],df=df)
# Out:
#   0%|          | 0/6335 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4d232b3a782d> in <module>()
#       5
#       6 for i in tqdm(range(len(df))):
# ----> 7     df.loc[i, 'f_win_strk'] = get_win_streak(name=df.loc[i,'fighter'],date=df.loc[i,'date'],df=df)
#       8     df.loc[i, 'o_win_strk'] = get_win_streak(name=df.loc[i,'opponent'],date=df.loc[i,'date'],df=df)
#       9     df.loc[i, 'f_lose_strk'] = get_lose_streak(name=df.loc[i,'fighter'],date=df.loc[i,'date'],df=df)
#
# TypeError: get_win_streak() got an unexpected keyword argument 'name'

# %%
>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
#   File "<ipython-input-28-a1528d4cf6f2>", line 1
#     >>>>>>>>>>>>>>>>>>>>>>>>>
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> feature total fight time (in minutes)

# %%
df['ttime'] = None

for rnd, time, i in zip(df['round'], df['time'], range(0,len(df))):
    rnd = int(rnd)
    minutes = int(time[0:time.find(':')])
    seconds = int(time[time.find(':')+1:])
    ttime = ((rnd - 1)*5*60 + minutes*60 + seconds)/60 
    df.loc[i,'ttime'] = round(ttime, 3)
    
df.head(3)

# %%
main_df = df

# %% [markdown]
# # <span style='color:green'> **[done]** </span> Merge data frames
# extracting data from fighters.csv(=stats_df) and add it to fights.csv(=main_df)

# %%
stat_df.head()

# %%
df = main_df.reset_index(drop=True)
df.head(3)

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> add new empty columns:

# %%
original_columns_list = main_df.columns

w_column_list = ['w_' + column for column in stat_df.columns[1:]]
l_column_list = ['l_' + column for column in stat_df.columns[1:]]
new_column_list = w_column_list + l_column_list

for column in new_column_list:
    main_df[column] = None

main_df.columns

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> add data to new stats columns:

# %%
for index in tqdm(range(0,len(main_df))):
    
    w_fighter = main_df.loc[index, 'w_fighter']
    l_fighter = main_df.loc[index, 'l_fighter']
    
    new_row = main_df.loc[index,original_columns_list]
    new_row = np.append(new_row, [get_fighter_stats(name=w_fighter, data=stat_df )])
    new_row = np.append(new_row, [get_fighter_stats(name=l_fighter, data=stat_df )])
    main_df.iloc[index] = new_row

main_df.tail(3)

# %% [markdown]
# ### <span style='color:green'> **[done]** </span> filter stat columns (where there is no details = '--'):

# %%
for stat in ['kd','str','td','sub']:
    main_df = main_df[~((main_df['l_'+stat]=='--')|(main_df['w_'+stat]=='--'))].reset_index(drop=True)

main_df.tail(3)

# %%
main_df.to_csv('../data/ufc_data.csv')
